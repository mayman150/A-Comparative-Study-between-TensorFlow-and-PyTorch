# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Tensorflow_issues.csv_0.csv', encoding='utf-8')

# %%
df
# Out:
#       Issue Number                                        Issue Title  \
# 0            62271  Documentation of `tf.nn.depthwise_conv2d` fail...
# 1            62270  Shape problems in LSTM; Configuring LSTM prope...
# 2            62269  Different Behavior of tf.raw_ops.Sin+tf.raw_op...
# 3            62268  Different Behavior of tf.raw_ops.ReciprocalGra...
# 4            62267  Different Behavior of tf.raw_ops.IgammaGradA+t...
# ...            ...                                                ...
# 9995         44099                          Feature request: ResNet34
# 9996         44098  Custom function adding before augmentation in ...
# 9997         44095                             installation for Torch
# 9998         44093  tf.distribute.MirroredStrategy using TF_CONFIG...
# 9999         44092  Loss of shape information when using dilation_...
#
#                                              Issue Body  \
# 0     ### Issue type\n\nDocumentation Bug\n\n### Hav...
# ...

# %%
#get the example number 2
print("TITLE: " ,df.iloc[1]['Issue Title'])
print("BODY: " , df.iloc[1]['Issue Body'])
# Out:
# TITLE:  0    Documentation of `tf.nn.depthwise_conv2d` fail...
# Name: Issue Title, dtype: object
# BODY:  0    ### Issue type\n\nDocumentation Bug\n\n### Hav...
# Name: Issue Body, dtype: object
